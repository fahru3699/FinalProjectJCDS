# %%
import pandas as pd
import numpy as np

# %% [markdown]
# - Import Total Population Data

# %%
dp = pd.read_csv('pop.csv')
dp
# Out:
#     Country (or dependency)  Population (2020) Yearly Change  Net Change  \
# 0                     China         1440297825        0.39 %     5540090
# 1                     India         1382345085        0.99 %    13586631
# 2             United States          331341050        0.59 %     1937734
# 3                 Indonesia          274021604        1.07 %     2898047
# 4                  Pakistan          221612785        2.00 %     4327022
# ..                      ...                ...           ...         ...
# 230              Montserrat               4993        0.06 %           3
# 231        Falkland Islands               3497        3.05 %         103
# 232                    Niue               1628        0.68 %          11
# 233                 Tokelau               1360        1.27 %          17
# 234                Holy See                801        0.25 %           2
#
#      Density (P/Km²)  Land Area (Km²)  Migrants (net) Fert. Rate Med. Age  \
# ...

# %% [markdown]
# - Split data to Country and Number of Population

# %%
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# %%
dp['Population (2020)'].describe()
# Out:
# count          235.000
# mean      33227444.281
# std      135303438.497
# min            801.000
# 25%         399490.500
# 50%        5460109.000
# 75%       20671699.500
# max     1440297825.000
# Name: Population (2020), dtype: float64

# %%
col_list = ["Country (or dependency)", "Population (2020)"]
dfp = pd.read_csv("pop.csv", usecols=col_list)
dfp
# Out:
#     Country (or dependency)  Population (2020)
# 0                     China         1440297825
# 1                     India         1382345085
# 2             United States          331341050
# 3                 Indonesia          274021604
# 4                  Pakistan          221612785
# ..                      ...                ...
# 230              Montserrat               4993
# 231        Falkland Islands               3497
# 232                    Niue               1628
# 233                 Tokelau               1360
# 234                Holy See                801
#
# [235 rows x 2 columns]

# %%
dfp.to_csv('02 - Country.csv', index=False)

# %%
df_clean = pd.read_csv('01 - CVP.csv')
df_clean.head()
# Out:
#    Unnamed: 0  country Country Code        date  Total Vaccinations  \
# 0           0  Algeria          DZA  2021-01-29               0.000
# 1           1  Algeria          DZA  2021-01-30              30.000
# 2           2  Andorra          AND  2021-01-25             576.000
# 3           3  Andorra          AND  2021-01-26               0.000
# 4           4  Andorra          AND  2021-01-27               0.000
#
#    Total People Vaccinated  People vaccinated  Daily Vaccinations Raw  \
# 0                    0.000              0.000                   0.000
# 1                    0.000              0.000                  30.000
# 2                  576.000              0.000                   0.000
# 3                    0.000              0.000                   0.000
# 4                    0.000              0.000                   0.000
#
#    Daily Vaccinations  Total 100  People Vaccinated 100  \
# 0               0.000      0.000                  0.000
# ...

# %%
df_clean.replace(np.nan, 0)
# Out:
#       Unnamed: 0  country Country Code        date  Total Vaccinations  \
# 0              0  Algeria          DZA  2021-01-29               0.000
# 1              1  Algeria          DZA  2021-01-30              30.000
# 2              2  Andorra          AND  2021-01-25             576.000
# 3              3  Andorra          AND  2021-01-26               0.000
# 4              4  Andorra          AND  2021-01-27               0.000
# ...          ...      ...          ...         ...                 ...
# 2059        2059    Wales            0  2021-01-28          362970.000
# 2060        2060    Wales            0  2021-01-29          378950.000
# 2061        2061    Wales            0  2021-01-30          404249.000
# 2062        2062    Wales            0  2021-01-31          417147.000
# 2063        2063    Wales            0  2021-02-01          440706.000
#
#       Total People Vaccinated  People vaccinated  Daily Vaccinations Raw  \
# ...

# %%
col_list = ["country", "date", "Total Vaccinations", "Daily Vaccinations", "People Vaccinated 100", "Daily Vaccination 1 mio", "Vaccines"]
dfn = pd.read_csv("01 - CVP.csv", usecols=col_list)
dfn
# Out:
#       country        date  Total Vaccinations  Daily Vaccinations  \
# 0     Algeria  2021-01-29               0.000               0.000
# 1     Algeria  2021-01-30              30.000              30.000
# 2     Andorra  2021-01-25             576.000               0.000
# 3     Andorra  2021-01-26               0.000              66.000
# 4     Andorra  2021-01-27               0.000              66.000
# ...       ...         ...                 ...                 ...
# 2059    Wales  2021-01-28          362970.000           21463.000
# 2060    Wales  2021-01-29          378950.000           19705.000
# 2061    Wales  2021-01-30          404249.000           19885.000
# 2062    Wales  2021-01-31          417147.000           20824.000
# 2063    Wales  2021-02-01          440706.000           21508.000
#
#       People Vaccinated 100  Daily Vaccination 1 mio  \
# 0                     0.000                    0.000
# 1                     0.000                    1.000
# ...

# %%
dfn.to_csv('02 - CVP.csv', index=False)
